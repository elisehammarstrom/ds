# %% [markdown]
# # Chapter 1

# %%
# exercise 21
p = 0.3
n=1000
no_of_heads = 0

import numpy as np

np.random.seed(0)

X1 = np.where(np.random.uniform(low=0, high=1, size=n) < 0.3, 1, 0) 
X2 = np.where(np.random.uniform(low=0, high=1, size=n) < 0.03, 1, 0) 

import matplotlib.pyplot as plt

nn = np.arange(1, n + 1)

plt.figure(figsize=(12, 8))
plt.plot(nn, np.cumsum(X1) / nn, label='p = 0.3')
plt.plot(nn, np.cumsum(X2) / nn, label='p = 0.03')
plt.legend(loc='upper right')
plt.show()

# %%
#exercise 22

p = 0.3
n = 1000 #n=10, 100, 1000
#n_array = [10, 100, 1000]
X_comparison_intuition = n*p

X_test_results = []

for iteration in range(0,n):
    X_test = np.where(np.random.uniform(low=0, high=1, size=n) < p, 1, 0) 
    sum_X = np.sum(X_test)
    X_test_results.append(sum_X)

average_X_test = np.sum(X_test_results)/len(X_test_results)

#average_X_test = X_test_results.mean() 



print("average_X_test: ", average_X_test,"X_comparison_intuition: ", X_comparison_intuition )
# Out:
# average_X_test:  299.749 X_comparison_intuition:  300.0

# %%
#exercise 23

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

np.random.seed(0)

B = 10000 #no of simulations
results = np.random.randint(low=1, high=7, size=B)

A_hat = np.isin(results, [2, 4, 6])
B_hat = np.isin(results, [1, 2, 3, 4])
AB_hat = np.isin(results, [2, 4])

nn = np.arange(1, B + 1) #this is only for plotting

f, (a0, a1) = plt.subplots(2, 1, gridspec_kw={'height_ratios': [3, 1]}, figsize=(12, 8))

a0.plot(nn, np.cumsum(A_hat) / nn, label=r'$\hat{P}(A)$')
a0.plot(nn, np.cumsum(B_hat) / nn, label=r'$\hat{P}(B)$')
a0.plot(nn, np.cumsum(AB_hat) / nn, label=r'$\hat{P}(AB)$')
a0.plot(nn, np.cumsum(A_hat) * np.cumsum(B_hat) / (nn * nn), label=r'$\hat{P}(A) \hat{P}(B)$')
a0.legend(loc='upper right')

a1.plot(nn, np.cumsum(A_hat) * np.cumsum(B_hat) / (nn * nn) - np.cumsum(AB_hat) / nn, 
         label=r'$\hat{P}(A) \hat{P}(B)- \hat{P}(AB)$', color='purple')
a1.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
#part 2 of exercise 23, find two events A and B that are not independent
A_hat = np.isin(results, [2, 4, 6])
B_hat = np.isin(results, [2, 4, 5])
AB_hat = np.isin(results, [2, 4])

f, (a0, a1) = plt.subplots(2, 1, gridspec_kw={'height_ratios': [3, 1]}, figsize=(12, 8))

a0.plot(nn, np.cumsum(A_hat) / nn, label=r'$\hat{P}(A)$')
a0.plot(nn, np.cumsum(B_hat) / nn, label=r'$\hat{P}(B)$')
a0.plot(nn, np.cumsum(AB_hat) / nn, label=r'$\hat{P}(AB)$')
a0.plot(nn, np.cumsum(A_hat) * np.cumsum(B_hat) / (nn * nn), label=r'$\hat{P}(A) \hat{P}(B)$')
a0.legend(loc='upper right')

a1.plot(nn, np.cumsum(A_hat) * np.cumsum(B_hat) / (nn * nn) - np.cumsum(AB_hat) / nn, 
         label=r'$\hat{P}(A) \hat{P}(B)- \hat{P}(AB)$', color='purple')
a1.legend(loc='upper right')

plt.tight_layout()
plt.show()
